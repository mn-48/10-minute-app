# %% [markdown]
# <a href="https://colab.research.google.com/github/Md-NazmulHossain/10-minute-app/blob/master/CSESFI_12_Palindrome_Reorder.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = input()
ls = sorted(list(set(a)))

middle = ''
half = ''
x = 0

for i in ls:
  n = a.count(i)
  if n%2==0:
    half += i* (n//2)
  elif x==1:
    half = 0
    print("NO SOLUTION")
    break;

  else:
    x =1
    middle = i
    half += i* (n//2)

if half !=0:
  print(half+middle+half[::-1])
# Out:
# Mother
# NO SOLUTION
